# %%
# help functions from https://github.com/dalab/lecture_cil_public/blob/master/exercises/2019/ex11_old/segment_aerial_images.ipynb
# %matplotlib inline
from scipy.ndimage import rotate
import matplotlib.image as mpimg
import numpy as np
import re
import matplotlib.pyplot as plt
import os,sys
import datetime
from PIL import Image
from IPython.display import clear_output
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization, Conv2DTranspose, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Input
import sklearn.model_selection as sk

# %%
from albumentations import (
    PadIfNeeded,
    HorizontalFlip,
    VerticalFlip,    
    CenterCrop,    
    Crop,
    Compose,
    Transpose,
    RandomRotate90,
    ElasticTransform,
    GridDistortion, 
    OpticalDistortion,
    RandomSizedCrop,
    OneOf,
    CLAHE,
    RandomBrightnessContrast,    
    RandomGamma,
    RGBShift,
    RandomContrast,
    RandomBrightness,
    HueSaturationValue,
    ShiftScaleRotate,
    ToFloat
)

# %%
import cv2

# %%
print(tf.__version__)
# Out:
# 2.2.0

# %%
import os
from getpass import getpass
import urllib

user = input('User name: ')
password = getpass('Password: ')
password = urllib.parse.quote(password) # your password is converted into url format
# repo_name = input('Repo name: ')

# cmd_string = 'git clone https://{0}:{1}@github.com/{0}/{2}.git'.format(user, password, repo_name)
cmd_string = 'git clone https://{0}:{1}@github.com/JonathanLehner/CIL-street.git'.format(user, password)

os.system(cmd_string)
cmd_string, password = "", "" # removing the password from the variable
# Out:
# User name: matejsladek
# Password: ··········

# %%
CROP_SIZE = 64
PATCH_SIZE = 16

# %%
# Helper functions

def load_image(infilename):
    data = mpimg.imread(infilename)
    return data

def img_float_to_uint8(img):
    rimg = img - np.min(img)
    rimg = (rimg / np.max(rimg) * 255).round().astype(np.uint8)
    return rimg

# Concatenate an image and its groundtruth
def concatenate_images(img, gt_img):
    nChannels = len(gt_img.shape)
    w = gt_img.shape[0]
    h = gt_img.shape[1]
    if nChannels == 3:
        cimg = np.concatenate((img, gt_img), axis=1)
    else:
        gt_img_3c = np.zeros((w, h, 3), dtype=np.uint8)
        gt_img8 = img_float_to_uint8(gt_img)
        gt_img_3c[:,:,0] = gt_img8
        gt_img_3c[:,:,1] = gt_img8
        gt_img_3c[:,:,2] = gt_img8
        img8 = img_float_to_uint8(img)
        cimg = np.concatenate((img8, gt_img_3c), axis=1)
    return cimg

def img_crop(im, w, h):
    list_patches = []
    imgwidth = im.shape[0]
    imgheight = im.shape[1]
    is_2d = len(im.shape) < 3
    for i in range(0,imgheight,h):
        for j in range(0,imgwidth,w):
            if is_2d:
                im_patch = im[j:j+w, i:i+h]
            else:
                im_patch = im[j:j+w, i:i+h, :]
            list_patches.append(im_patch)
    return list_patches

# %%
def img_crop_64(im, w, h):
    imgwidth = im.shape[0]
    imgheight = im.shape[1]
    is_2d = len(im.shape) < 3
    if is_2d:
        im_padded = np.pad(im, ((CROP_SIZE,CROP_SIZE),(CROP_SIZE,CROP_SIZE)), 'constant')
    else:
        im_padded = np.pad(im, ((CROP_SIZE,CROP_SIZE),(CROP_SIZE,CROP_SIZE), (0,0)), 'constant')
    im = im_padded
    list_patches = []
    for i in range(0,imgheight,h):
        for j in range(0,imgwidth,w):
            num = (CROP_SIZE-PATCH_SIZE)//2
            if is_2d:
#                 im_patch = im[64+j-24:64+j+w+24, 64+i-24:64+i+h+24]
                im_patch = im[CROP_SIZE+j-num:CROP_SIZE+j+w+num, CROP_SIZE+i-num:CROP_SIZE+i+h+num]
            else:
                im_patch = im[CROP_SIZE+j-num:CROP_SIZE+j+w+num, CROP_SIZE+i-num:CROP_SIZE+i+h+num, :]
#                 print("3d", i, j, im_patch.shape)
            list_patches.append(im_patch)
            # list_patches.append(rotate(im_patch, 90))
            # list_patches.append(rotate(im_patch, 180))
            # list_patches.append(rotate(im_patch, 270))
    return list_patches
# A = 

# print(imgs[1].shape)
# b = img_crop(imgs[1], 16,16)
# a = img_crop_64(imgs[1], 16,16)
# print(b[0].shape)
# print(a[0].shape)
# print(imgs[1].shape)

# %%
# Convert array of labels to an image

def label_to_img(imgwidth, imgheight, w, h, labels):
    im = np.zeros([imgwidth, imgheight])
    idx = 0
    for i in range(0,imgheight,h):
        for j in range(0,imgwidth,w):
            im[j:j+w, i:i+h] = labels[idx]
            idx = idx + 1
    return im

def label_to_img_unet(imgwidth, imgheight, w, h, labels):
    im = np.zeros([imgwidth, imgheight])
    idx = 0
    for i in range(0,imgheight,h):
        for j in range(0,imgwidth,w):
            num = (CROP_SIZE-PATCH_SIZE)//2
            patch = labels[idx][num:CROP_SIZE-num, num:CROP_SIZE-num, :]
            im[j:j+w, i:i+h] = patch[:, :, 0]
            idx = idx + 1
    return im

def make_img_overlay(img, predicted_img):
    w = img.shape[0]
    h = img.shape[1]
    color_mask = np.zeros((w, h, 3), dtype=np.uint8)
    color_mask[:,:,0] = predicted_img*255

    img8 = img_float_to_uint8(img)
    background = Image.fromarray(img8, 'RGB').convert("RGBA")
    overlay = Image.fromarray(color_mask, 'RGB').convert("RGBA")
    new_img = Image.blend(background, overlay, 0.2)
    return new_img

# %%
# Loaded a set of images
repo_dir = "/content/CIL-street/"
data_dir = repo_dir + "data/"
training_dir = data_dir + "training/"
test_dir = data_dir + "test_images/"

image_dir = training_dir + "images/"
image_dir_orig = training_dir + "images_pix_256/"
files = os.listdir(image_dir)
n = len(files) # Load maximum 20 images
print("Loading " + str(n) + " images")
imgs = [load_image(image_dir + files[i]) for i in range(n)]
train_imgs_idx = files;
print(files[0])

gt_dir = training_dir + "groundtruth/"
print("Loading " + str(n) + " gt images")
gt_imgs = [load_image(gt_dir + files[i]) for i in range(n)]
print(files[0])

# n = 10 # Only use 10 images for training
# Out:
# Loading 100 images
# satImage_033.png
# Loading 100 gt images
# satImage_033.png

# %%
# transform to 400x400
# files = os.listdir(image_dir_orig)
# n = len(files)
# imgs = [(files[i], load_image(image_dir_orig + files[i])) for i in range(n)]
# for name, f in imgs:
#     save_path = image_dir + name
#     image = tf.image.resize(f, size=(400,400), method=tf.image.ResizeMethod.BICUBIC)
#     tf.keras.preprocessing.image.save_img(save_path,image)

# %%
files = os.listdir(test_dir)
print("Loading " + str(len(files)) + " test images")
files
test_imgs = [load_image(test_dir + f) for f in files]
test_imgs_idx = files;
# Out:
# Loading 94 test images

# %%
test_imgs_idx[0]
# Out:
# 'test_177.png'

# %%
# Show first image and its groundtruth image
cimg = concatenate_images(imgs[0], gt_imgs[0])
# cimg = concatenate_images(, gt_imgs[0])

fig1 = plt.figure(figsize=(10, 10))
plt.imshow(cimg, cmap='Greys_r')

# %%
# Extract patches from input images
patch_size = 16 # each patch is 16*16 pixels

img_patches = [img_crop_64(imgs[i], patch_size, patch_size) for i in range(n)]
# gt_patches = [img_crop(gt_imgs[i], patch_size, patch_size) for i in range(n)]
# unet
gt_patches = [img_crop_64(gt_imgs[i], patch_size, patch_size) for i in range(n)]

# Linearize list of patches
img_patches = np.asarray([img_patches[i][j] for i in range(len(img_patches)) for j in range(len(img_patches[i]))])
gt_patches =  np.asarray([gt_patches[i][j] for i in range(len(gt_patches)) for j in range(len(gt_patches[i]))])

# %%
patch_size = 16
test_patches = [img_crop_64(test_imgs[i], patch_size, patch_size) for i in range(len(test_imgs))]
# test_patches = [img_crop_64(test_imgs[i], patch_size, patch_size) for i in range(10)]
test_patches = np.asarray([test_patches[i][j] / 255.0 for i in range(len(test_patches)) for j in range(len(test_patches[i]))])

# %%
# a = np.asarray(test_patches)

# %%
# a.shape, test_patches2.shape

# %%
a.shape

# %%
# test_patches = test_patches

# %%
# img_patches = img_patches / 255.0

# %%
imgs[0].shape, gt_imgs[0].shape
# Out:
# ((400, 400, 3), (400, 400))

# %%
# gt_patches = [img_crop_64(gt_imgs[i], patch_size, patch_size) for i in range(n)]

# %%
# Compute features for each image patch
foreground_threshold = 0.25 # percentage of pixels > 1 required to assign a foreground label to a patch

def value_to_class(v):
    df = np.sum(v)
    if df > foreground_threshold:
        return 1
    else:
        return 0

# X = np.asarray([ extract_features_2d(img_patches[i]) for i in range(len(img_patches))])
# Y = np.asarray([value_to_class(np.mean(gt_patches[i])) for i in range(len(gt_patches))])
# patches
# X = np.asarray([ img_patches[i] for i in range(len(img_patches))])
# Y = np.asarray([value_to_class(np.mean(gt_patches[i])) for i in range(len(gt_patches))])
# unet
# X = np.asarray([ (img_patches[i] / 255.0) for i in range(len(img_patches))])
# Y = np.asarray([ (gt_patches[i] / 255.0) for i in range(len(gt_patches))])
X = img_patches / 255.0
# Y = gt_patches
Y = tf.where(gt_patches > 0, np.dtype('uint8').type(1), gt_patches)

# %%
img_patches, gt_patches = None, None

# %%
X.shape, Y.shape
# Out:
# ((62500, 64, 64, 3), TensorShape([62500, 64, 64]))

# %%
Y = np.expand_dims(Y, -1)

# %%
X.shape, Y.shape
# Out:
# ((62500, 64, 64, 3), (62500, 64, 64, 1))

# %%
indices = np.arange(X.shape[0])

# %%
X_train, X_test, y_train, y_test, indices_train, indices_test = sk.train_test_split(X,Y,indices,test_size=0.20, random_state = 42)

# %%
min(indices_test)
# Out:
# 4

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape, indices_train.shape, indices_test.shape
# Out:
# ((50000, 64, 64, 3),
#  (12500, 64, 64, 3),
#  (50000, 64, 64, 1),
#  (12500, 64, 64, 1),
#  (50000,),
#  (12500,))

# %%
# taken from a blog post
# -- Keras Functional API -- #
# -- UNet Implementation -- #
# Everything here is from tensorflow.keras.layers
# I imported tensorflow.keras.layers * to make it easier to read

input_size = (CROP_SIZE, CROP_SIZE, 3)

# Contracting Path (encoding)
inputs = Input(input_size)

conv1 = Conv2D(16, 3, activation='elu', padding='same', kernel_initializer='he_normal')(inputs)
conv1 = BatchNormalization()(conv1)
conv1 = Dropout(0.1)(conv1)
conv1 = Conv2D(16, 3, activation='elu', padding='same', kernel_initializer='he_normal')(conv1)
conv1 = BatchNormalization()(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(32, 3, activation='elu', padding='same', kernel_initializer='he_normal')(pool1)
conv2 = BatchNormalization()(conv2)
conv2 = Dropout(0.1)(conv2)
conv2 = Conv2D(32, 3, activation='elu', padding='same', kernel_initializer='he_normal')(conv2)
conv2 = BatchNormalization()(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(64, 3, activation='elu', padding='same', kernel_initializer='he_normal')(pool2)
conv3 = BatchNormalization()(conv3)
conv3 = Dropout(0.2)(conv3)
conv3 = Conv2D(64, 3, activation='elu', padding='same', kernel_initializer='he_normal')(conv3)
conv3 = BatchNormalization()(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(128, 3, activation='elu', padding='same', kernel_initializer='he_normal')(pool3)
conv4 = BatchNormalization()(conv4)
conv4 = Dropout(0.2)(conv4)
conv4 = Conv2D(128, 3, activation='elu', padding='same', kernel_initializer='he_normal')(conv4)
conv4 = BatchNormalization()(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(256, 3, activation='elu', padding='same', kernel_initializer='he_normal')(pool4)
conv5 = BatchNormalization()(conv5)
conv5 = Dropout(0.3)(conv5)
conv5 = Conv2D(256, 3, activation='elu', padding='same', kernel_initializer='he_normal')(conv5)
conv5 = BatchNormalization()(conv5)

# Expansive Path (decoding)
up6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv5)
merge6 = concatenate([up6, conv4])
conv6 = Conv2D(128, 3, activation='elu', padding='same', kernel_initializer='he_normal')(merge6)
conv6 = BatchNormalization()(conv6)
conv6 = Dropout(0.2)(conv6)
conv6 = Conv2D(128, 3, activation='elu', padding='same', kernel_initializer='he_normal')(conv6)
conv6 = BatchNormalization()(conv6)

up7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv6)
merge7 = concatenate([up7, conv3])
conv7 = Conv2D(64, 3, activation='elu', padding='same', kernel_initializer='he_normal')(merge7)
conv7 = BatchNormalization()(conv7)
conv7 = Dropout(0.2)(conv7)
conv7 = Conv2D(64, 3, activation='elu', padding='same', kernel_initializer='he_normal')(conv7)
conv7 = BatchNormalization()(conv7)

up8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv7)
merge8 = concatenate([up8, conv2])
conv8 = Conv2D(32, 3, activation='elu', padding='same', kernel_initializer='he_normal')(merge8)
conv8 = BatchNormalization()(conv8)
conv8 = Dropout(0.1)(conv8)
conv8 = Conv2D(32, 3, activation='elu', padding='same', kernel_initializer='he_normal')(conv8)
conv8 = BatchNormalization()(conv8)

up9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(conv8)
merge9 = concatenate([up9, conv1])
conv9 = Conv2D(16, 3, activation='elu', padding='same', kernel_initializer='he_normal')(merge9)
conv9 = BatchNormalization()(conv9)
conv9 = Dropout(0.1)(conv9)
conv9 = Conv2D(16, 3, activation='elu', padding='same', kernel_initializer='he_normal')(conv9)
conv9 = BatchNormalization()(conv9)

conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

model = tf.keras.Model(inputs=inputs, outputs=conv10)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64, 64, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 16)   2320        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 64)   36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 64)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 128)    73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 128)    147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 256)    295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 256)    1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 256)    590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 4, 256)    1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 128)    131200      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 256)    0           conv2d_transpose[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 128)    295040      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 128)    512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 128)    147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   32832       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 128)  0           conv2d_transpose_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 32)   8224        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 64)   0           conv2d_transpose_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 32)   18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 32)   128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 32)   9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 16)   2064        batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 32)   0           conv2d_transpose_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 16)   4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 16)   64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64, 64, 16)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 16)   2320        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 16)   64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 1)    17          batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 1,946,993
# Trainable params: 1,944,049
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
model = Sequential([
    Conv2D(16, 3, padding='same', activation='relu', input_shape=(64, 64, 3)),
    MaxPooling2D(),
    BatchNormalization(),
    Dropout(0.5),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    BatchNormalization(),
    Dropout(0.5),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    BatchNormalization(),
    Dropout(0.5),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1)
])

# %%
model = Sequential([
#     Conv2D(16, 3, padding='same', activation='relu', input_shape=(patch_size, patch_size, 3)),
    Conv2D(16, 3, padding='same', activation='relu', input_shape=(64, 64, 3)),
    MaxPooling2D(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Flatten(),
#     Dense(512, activation='relu'),
#     Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1)
])

# %%
model = VGG16(weights="imagenet", include_top=False,
input_tensor=Input(shape=(64, 64, 3)))
model.trainable = False
pretrained_model = model
# model.summary()
model = tf.keras.Sequential([
    pretrained_model,
    Flatten(),
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1)
])
# model.add(keras.layers.Flatten())
# model.add(keras.layers.Dense(1024, activation="relu"))
# model.add(keras.layers.Dense(1, activation="relu"))

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               524416
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 548,129
# Trainable params: 548,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
# unet compile
def dice_coef(y_true, y_pred, smooth = 1):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)


def soft_dice_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

model.compile(optimizer=Adam(0.0001), loss = soft_dice_loss,
              metrics=['accuracy'])

# %%
log_dir="logs/fit"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
filepath="weights/weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
model.fit(X_train,
          y_train,
          epochs=100,
          shuffle=True,
          validation_data=(X_test, y_test),
          callbacks=[
                keras.callbacks.EarlyStopping(
                    patience=5,
                    restore_best_weights=True,
                ),
                tensorboard_callback,
#                 checkpoint
          ])
# Out:
# Train on 50000 samples, validate on 12500 samples
# Epoch 1/100
# 12928/50000 [======>.......................] - ETA: 2:00 - loss: 0.5882 - accuracy: 0.7381WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 12928/50000 [======>.......................] - ETA: 2:01 - loss: 0.5882 - accuracy: 0.7381
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-ee14054ecd01> in <module>
#       9                     restore_best_weights=True,
#      10                 ),
# ---> 11                 tensorboard_callback,
#      12 #                 checkpoint
#      13           ])
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
datagen = ImageDataGenerator(
    # featurewise_center=True,
    # featurewise_std_normalization=True,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=90,
    width_shift_range=5,
    height_shift_range=5,
    horizontal_flip=True,
    vertical_flip=True)
# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen.fit(X_train)
# datagen.fit(y_train)
# fits the model on batches with real-time data augmentation:
# model.fit(datagen.flow(x_train, y_train, batch_size=32),
          # steps_per_epoch=len(x_train) / 32, epochs=epochs)

# %%
model.fit(datagen.flow(X_train, y_train, batch_size=32),
          steps_per_epoch=len(X_train) / 32, epochs=100,
          validation_data=(X_test, y_test),
          callbacks=[
                keras.callbacks.EarlyStopping(
                    patience=5,
                    restore_best_weights=True,
                ),
                tensorboard_callback,
#                 checkpoint
          ])

# %%
X_train[0].shape, y_train[0].shape
# Out:
# ((64, 64, 3), (64, 64, 1))

# %%
def display_sample(display_list):
    """Show side-by-side an input image,
    the ground truth and the prediction.
    """
    plt.figure(figsize=(18, 18))

    title = ['Input Image', 'True Mask', 'Predicted Mask'] * 100

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

display_sample([X_train[1], y_train[1]])

# %%
# unet
def show_predictions(dataset=None, num=1):
    """Show a sample prediction.
    """
    idx = random.randint(0, X_test.shape[0])
    print(idx)
    sample = X_test[idx]
    sample = np.expand_dims(sample, 0)
    pred_mask = model.predict(sample)
    display_sample([X_test[idx], y_test[idx], pred_mask[0]])

show_predictions()
# Out:
# 8635

# %%
data_gen_args = dict(
  # rotation_range=180.,
  # width_shift_range=0.2,
  # height_shift_range=0.2,
  # fill_mode="constant",
  # cval=0,
  # horizontal_flip=True,
  # vertical_flip=True
)
image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)

# %%
# image_datagen.fit(X_train, augment=True, seed=seed)
# mask_datagen.fit(y_train, augment=True, seed=seed)

# %%
seed = 1
image_generator = image_datagen.flow(X_train, batch_size=8, seed=seed)
mask_generator = mask_datagen.flow(y_train, batch_size=8, seed=seed)

# train_generator = zip(image_generator, mask_generator)

# %%
aug = Compose([
    VerticalFlip(p=0.5),
    HorizontalFlip(p=0.5),
    RandomRotate90(p=0.5),
])

# %%
AUGMENTATIONS_TRAIN = Compose([
    HorizontalFlip(p=0.5),
    RandomContrast(limit=0.2, p=0.5),
    RandomGamma(gamma_limit=(80, 120), p=0.5),
    RandomBrightness(limit=0.2, p=0.5),
    # HueSaturationValue(hue_shift_limit=5, sat_shift_limit=20,
                      #  val_shift_limit=10, p=.9),
    # CLAHE(p=1.0, clip_limit=2.0),
    # ShiftScaleRotate(
        # shift_limit=0.0625, scale_limit=0.1, 
        # rotate_limit=15, border_mode=cv2.BORDER_REFLECT_101, p=0.8), 
    # ToFloat(max_value=255)
])

# %%
class Better_generator:
    def __init__(self, im_gen, mask_gen, aug):
        self.im_gen, self.mask_gen, self.aug = im_gen, mask_gen, aug
    def __iter__(self):
        while True:
            nxt_img = self.im_gen.next()
            nxt_mask = self.mask_gen.next()
            img = []
            mask = []
            for (x, y) in zip(nxt_img, nxt_mask):
              augmented = self.aug(image=x, mask=y)
              img.append(augmented["image"])
              mask.append(augmented["mask"])
            img = np.stack(img, axis=0)
            mask = np.stack(mask, axis=0)
            # print(img.shape, mask.shape)
            yield img, mask
data_gen = Better_generator(image_generator, mask_generator, aug)

# %%
# for X_batch, y_batch in train_generator:
for X_batch, y_batch in data_gen:
  display_sample(X_batch)
  display_sample(y_batch)
  break

# %%
class DisplayCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        clear_output(wait=True)
        show_predictions()
        print ('\nSample Prediction after epoch {}\n'.format(epoch+1))

TRAINSET_SIZE = X_train.shape[0]
VALSET_SIZE = X_test.shape[0]
EPOCHS = 50
BATCH_SIZE = 16
STEPS_PER_EPOCH = max(TRAINSET_SIZE // BATCH_SIZE, 1)
VALIDATION_STEPS = max(VALSET_SIZE // BATCH_SIZE, 1)

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

callbacks = [
    # to show samples after each epoch
    DisplayCallback(),
    # to collect some useful metrics and visualize them in tensorboard
    tensorboard_callback,
    # if no accuracy improvements we can stop the training directly
    # tf.keras.callbacks.EarlyStopping(patience=10, verbose=1),
    # to save checkpoints
    # tf.keras.callbacks.ModelCheckpoint('best_model_unet.h5', verbose=1, save_best_only=True, save_weights_only=True)
    # tf.keras.callbacks.ModelCheckpoint('best_model_unet64crop.{epoch:03d}-{val_loss:.2f}-{val_accuracy:.2f}.h5', verbose=1, save_best_only=True, save_weights_only=True)
    # tf.keras.callbacks.ModelCheckpoint('best_model_unet64crop_aug.{epoch:03d}-{val_loss:.2f}-{val_accuracy:.2f}.h5', verbose=1, save_best_only=True, save_weights_only=True)
    tf.keras.callbacks.ModelCheckpoint('best_model_unet96crop_aug5.{epoch:03d}-{loss:.2f}-{val_loss:.2f}-{accuracy:.2f}-{val_accuracy:.2f}.h5', verbose=1, save_weights_only=True)
]

model_history = model.fit(
                          # X_train,
                          # y_train,
                          train_generator,
                          # validation_split=0.1,
                          validation_data=(X_test, y_test),
                          epochs=EPOCHS,
                          batch_size=BATCH_SIZE,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          callbacks=callbacks)
# Out:
# Epoch 1/50
#  247/3125 [=>............................] - ETA: 1:08 - loss: 0.7065 - accuracy: 0.4815
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-160-3721c0322e7a> in <module>()
#      38                           batch_size=BATCH_SIZE,
#      39                           steps_per_epoch=STEPS_PER_EPOCH,
# ---> 40                           callbacks=callbacks)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     853                 context.async_wait()
#     854               logs = tmp_logs  # No error, now safe to assign to logs.
# --> 855               callbacks.on_train_batch_end(step, logs)
#     856         epoch_logs = copy.copy(logs)
#     857
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     388     if self._should_call_train_batch_hooks:
#     389       logs = self._process_logs(logs)
# --> 390       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     391
#     392   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     299     self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#     300
# --> 301     delta_t_median = np.median(self._delta_ts[hook_name])
#     302     if (self._delta_t_batch > 0. and
#     303         delta_t_median > 0.95 * self._delta_t_batch and delta_t_median > 0.1):
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3493     """
#    3494     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3495                     overwrite_input=overwrite_input)
#    3496     if keepdims:
#    3497         return r.reshape(k)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3401         keepdim = (1,) * a.ndim
#    3402
# -> 3403     r = func(a, **kwargs)
#    3404     return r, keepdim
#    3405
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py in _median(a, axis, out, overwrite_input)
#    3546     if np.issubdtype(a.dtype, np.inexact) and sz > 0:
#    3547         # warn and return nans like mean would
# -> 3548         rout = mean(part[indexer], axis=axis, out=out)
#    3549         return np.lib.utils._median_nancheck(part, rout, axis, out)
#    3550     else:
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3333
#    3334     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3335                           out=out, **kwargs)
#    3336
#    3337
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     143     # Cast bool, unsigned int, and int to float64 by default
#     144     if dtype is None:
# --> 145         if issubclass(arr.dtype.type, (nt.integer, nt.bool_)):
#     146             dtype = mu.dtype('f8')
#     147         elif issubclass(arr.dtype.type, nt.float16):
#
# KeyboardInterrupt:

# %%
# model.save('my_model.h5')

# %%
# model = load_model('my_model3.h5')

# %%
model.load_weights("/content/best_model_unet96crop_aug3.001-0.14-0.21-0.94-0.92.h5")

# %%
print(1)
# Out:
# 1

# %%
test_patches.shape
# Out:
# (135736, 96, 96, 3)

# %%
#classification
prediction = model.predict(test_patches, verbose=1)
print(min(prediction), max(prediction))
prediction = (np.sign(prediction)+1)/2
print(min(prediction), max(prediction))
# Out:
#  178/4242 [>.............................] - ETA: 5:24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-0f8ec2c89ed9> in <module>()
#       1 #classification
# ----> 2 prediction = model.predict(test_patches, verbose=1)
#       3 print(min(prediction), max(prediction))
#       4 prediction = (np.sign(prediction)+1)/2
#       5 print(min(prediction), max(prediction))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      86       raise ValueError('{} is not supported in multi-worker mode.'.format(
#      87           method.__name__))
# ---> 88     return method(self, *args, **kwargs)
#      89
#      90   return tf_decorator.make_decorator(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1266           for step in data_handler.steps():
#    1267             callbacks.on_predict_batch_begin(step)
# -> 1268             tmp_batch_outputs = predict_function(iterator)
#    1269             # Catch OutOfRangeError for Datasets of unknown size.
#    1270             # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     616       # In this case we have not created variables on the first call. So we can
#     617       # run the first trace but we should fail if variables are created.
# --> 618       results = self._stateful_fn(*args, **kwds)
#     619       if self._created_variables:
#     620         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
prediction_train = model.predict(img_patches)
prediction_train = (np.sign(prediction_train)+1)/2

# %%
test_patches.shape, img_patches.shape
# Out:
# ((135736, 64, 64, 3), (62500, 64, 64, 3))

# %%
test_patches=None

# %%
#unet
prediction = model.predict(test_patches, verbose=1)
print(prediction.shape)
# display_sample([test_patches[1], prediction[1]])
# Out:
# 4242/4242 [==============================] - 475s 112ms/step
# (135736, 96, 96, 1)

# %%
#unet
prediction_train = model.predict(img_patches, verbose=1)
print(prediction_train.shape)
# display_sample([test_patches[1], prediction[1]])
# Out:
# 1954/1954 [==============================] - 146s 75ms/step
# (62500, 96, 96, 1)

# %%
# # Display prediction as an image
img_idx = 13
w = gt_imgs[img_idx].shape[0]
h = gt_imgs[img_idx].shape[1]
patches_per_image = int(w*h/16/16)
fr = patches_per_image*img_idx
to = patches_per_image*(img_idx+1)
labels = prediction_train[fr:to+1]
predicted_im = label_to_img(w, h, patch_size, patch_size, labels)
cimg = concatenate_images(imgs[img_idx], predicted_im)
fig1 = plt.figure(figsize=(10, 10)) # create a figure with the default size 
# plt.imshow(predicted_img, cmap='Greys_r')
plt.imshow(cimg, cmap='Greys_r')
# plt.imshow(overlay)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-155-446b9ebffa0a> in <module>
#       7 to = patches_per_image*(img_idx+1)
#       8 labels = prediction_train[fr:to+1]
# ----> 9 predicted_im = label_to_img(w, h, patch_size, patch_size, labels)
#      10 cimg = concatenate_images(imgs[img_idx], predicted_im)
#      11 fig1 = plt.figure(figsize=(10, 10)) # create a figure with the default size
#
# <ipython-input-148-d86af7fa8b5d> in label_to_img(imgwidth, imgheight, w, h, labels)
#       6     for i in range(0,imgheight,h):
#       7         for j in range(0,imgwidth,w):
# ----> 8             im[j:j+w, i:i+h] = labels[idx]
#       9             idx = idx + 1
#      10     return im
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
result_dir = repo_dir + "code/patch_based/results_unet/"
if not os.path.exists(result_dir):
    os.makedirs(result_dir)

# %%
def create_res_dirs(result_dir):
    prediction_dir = result_dir + "prediction/"
    concat_dir = result_dir + "concat/"
    overlay_dir = result_dir + "overlay/"
    for dr in [result_dir, prediction_dir, concat_dir, overlay_dir]:    
        if not os.path.exists(dr):
            os.makedirs(dr)

# %%
create_res_dirs(result_dir + "test/")
create_res_dirs(result_dir + "train/")
create_res_dirs(result_dir + "val/")

# %%
def eval_f(test_imgs, test_imgs_idx, prediction, result_dir, train=False, result_dir_val=""):
    result_dir_backup = result_dir
    for (i, name) in enumerate(test_imgs_idx):
        if train:
            if i in indices_test:
                result_dir = result_dir_val
            else:
                result_dir = result_dir_backup
        w = test_imgs[i].shape[0]
        h = test_imgs[i].shape[1]
        patches_per_image = int(w*h/16/16)
        fr = patches_per_image*i
        to = patches_per_image*(i+1)
        labels = prediction[fr:to+1]
        predicted_img = label_to_img(w, h, patch_size, patch_size, labels)
        original_img = test_imgs[i]
        overlay = make_img_overlay(original_img, predicted_img)
        cimg = concatenate_images(original_img, predicted_img)

        img_number = int(re.search(r"\d+", test_imgs_idx[i]).group(0))

        predicted_img = img_float_to_uint8(predicted_img)
        cimg = img_float_to_uint8(cimg)
        prediction_dir = result_dir + "prediction/"
        concat_dir = result_dir + "concat/"
        overlay_dir = result_dir + "overlay/"
        Image.fromarray(predicted_img).save(prediction_dir + "prediction_" + str(img_number) + ".png")
        Image.fromarray(cimg).save(concat_dir + "concat_" + str(img_number) + ".png")
        overlay.save(overlay_dir + "overlay_" + str(img_number) + ".png")

    #     fig1 = plt.figure(figsize=(10, 10)) # create a figure with the default size 
    #     plt.imshow(predicted_img, cmap='Greys_r')
    #     plt.imshow(cimg, cmap='Greys_r')
    #     plt.imshow(overlay)
    #     break

# %%
def eval_unet(test_imgs, test_imgs_idx, prediction, result_dir, train=False, result_dir_val=""):
    result_dir_backup = result_dir
    for (i, name) in enumerate(test_imgs_idx):
        if train:
            if i in indices_test:
                result_dir = result_dir_val
            else:
                result_dir = result_dir_backup
        w = test_imgs[i].shape[0]
        h = test_imgs[i].shape[1]
        patches_per_image = int(w*h/16/16)
        fr = patches_per_image*i
        to = patches_per_image*(i+1)
        labels = prediction[fr:to+1]
        # print(to)
#         predicted_img = label_to_img(w, h, patch_size, patch_size, labels)
        predicted_img = label_to_img_unet(w, h, patch_size, patch_size, labels)
        original_img = test_imgs[i]
        overlay = make_img_overlay(original_img, predicted_img)
        cimg = concatenate_images(original_img, predicted_img)

        img_number = int(re.search(r"\d+", test_imgs_idx[i]).group(0))

        predicted_img = img_float_to_uint8(predicted_img)
        cimg = img_float_to_uint8(cimg)
        prediction_dir = result_dir + "prediction/"
        concat_dir = result_dir + "concat/"
        overlay_dir = result_dir + "overlay/"
        Image.fromarray(predicted_img).save(prediction_dir + "prediction_" + str(img_number) + ".png")
        Image.fromarray(cimg).save(concat_dir + "concat_" + str(img_number) + ".png")
        overlay.save(overlay_dir + "overlay_" + str(img_number) + ".png")

    #     fig1 = plt.figure(figsize=(10, 10)) # create a figure with the default size 
    #     plt.imshow(predicted_img, cmap='Greys_r')
    #     plt.imshow(cimg, cmap='Greys_r')
    #     plt.imshow(overlay)
    #     break

# %%
eval_f(test_imgs, test_imgs_idx, prediction, result_dir + "test/")

# %%
eval_f(imgs, train_imgs_idx, prediction_train, result_dir + "train/", True, result_dir + "val/")
# Out:
# /Users/msladek/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':

# %%
prediction=None

# %%
eval_unet(test_imgs, test_imgs_idx, prediction, result_dir + "test/")

# %%
eval_unet(imgs, train_imgs_idx, prediction_train, result_dir + "train/", True, result_dir + "val/")

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-313216ee3432> in <module>
# ----> 1 tf.image.resize()
#
# TypeError: resize_images_v2() missing 2 required positional arguments: 'images' and 'size'

# %%
# !zip -r /content/resultsss.zip /content/CIL-street/code/patch_based/results_unet
# Out:
#   adding: content/CIL-street/code/patch_based/results_unet/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_28.png (deflated 3%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_74.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_7.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_14.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_4.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_92.png (deflated 31%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_65.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_44.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_88.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_36.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_80.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_55.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_16.png (deflated 5%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_66.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_6.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/prediction/prediction_49.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_6.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_4.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_16.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_80.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_92.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_36.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_66.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_88.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_44.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_74.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_7.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_55.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_14.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_65.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_49.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/concat/concat_28.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_65.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_88.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_16.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_4.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_36.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_28.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_74.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_66.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_44.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_14.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_6.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_49.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_92.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_80.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_55.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/val/overlay/overlay_7.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_206.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_128.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_11.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_51.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_155.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_12.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_7.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_14.png (deflated 2%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_152.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_216.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_201.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_191.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_41.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_145.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_187.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_205.png (deflated 2%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_189.png (deflated 2%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_142.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_92.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_90.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_139.png (deflated 2%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_26.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_105.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_122.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_64.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_65.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_40.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_151.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_204.png (deflated 11%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_154.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_8.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_169.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_108.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_107.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_50.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_221.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_170.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_54.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_159.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_36.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_121.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_124.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_175.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_27.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_79.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_21.png (deflated 3%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_25.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_140.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_10.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_218.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_23.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_76.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_200.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_80.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_138.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_207.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_168.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_123.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_116.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_129.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_211.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_223.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_177.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_174.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_202.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_15.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_190.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_137.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_157.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_93.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_131.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_143.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_153.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_192.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_215.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_9.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_196.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_49.png (deflated 3%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_208.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_29.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_220.png (deflated 4%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_69.png (deflated 2%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_106.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_144.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_115.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_162.png (deflated 3%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_61.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_219.png (deflated 7%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_161.png (deflated 5%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_176.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_130.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_136.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_222.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/prediction/prediction_186.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_140.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_137.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_219.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_142.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_201.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_169.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_128.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_27.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_223.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_12.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_190.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_10.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_9.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_21.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_157.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_115.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_174.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_175.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_170.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_144.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_15.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_121.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_222.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_107.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_153.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_200.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_218.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_106.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_211.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_69.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_80.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_130.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_116.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_186.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_92.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_122.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_168.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_36.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_208.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_123.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_159.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_90.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_61.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_221.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_64.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_177.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_176.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_51.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_162.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_202.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_136.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_76.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_196.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_50.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_152.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_79.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_189.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_191.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_154.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_105.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_8.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_205.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_139.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_161.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_192.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_129.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_40.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_108.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_11.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_151.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_145.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_216.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_220.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_54.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_204.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_131.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_7.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_29.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_187.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_138.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_14.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_41.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_215.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_93.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_65.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_23.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_155.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_143.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_206.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_26.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_25.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_49.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_207.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/concat/concat_124.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_201.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_65.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_123.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_106.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_162.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_115.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_131.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_192.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_196.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_143.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_144.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_64.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_170.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_207.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_40.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_51.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_175.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_128.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_108.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_186.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_8.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_138.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_219.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_153.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_90.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_220.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_221.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_154.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_76.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_54.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_69.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_23.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_26.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_129.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_159.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_36.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_190.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_61.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_151.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_169.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_139.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_9.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_107.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_12.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_157.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_218.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_136.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_202.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_161.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_140.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_93.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_187.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_174.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_204.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_152.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_122.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_215.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_176.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_27.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_11.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_50.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_14.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_41.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_142.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_105.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_177.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_21.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_137.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_168.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_211.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_200.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_145.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_208.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_15.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_25.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_191.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_223.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_121.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_49.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_92.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_80.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_10.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_216.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_29.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_79.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_124.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_155.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_116.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_206.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_205.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_189.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_222.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_130.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/test/overlay/overlay_7.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_97.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_63.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_11.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_3.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_51.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_12.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_83.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_31.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_98.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_77.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_35.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_41.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_86.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_1.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_45.png (deflated 2%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_43.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_90.png (deflated 2%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_26.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_64.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_91.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_52.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_40.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_95.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_57.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_48.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_33.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_8.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_82.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_67.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_50.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_78.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_18.png (deflated 4%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_19.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_20.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_22.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_37.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_24.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_54.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_71.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_39.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_81.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_53.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_27.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_34.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_79.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_70.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_21.png (deflated 2%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_25.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_62.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_10.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_46.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_23.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_76.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_96.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_13.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_87.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_59.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_60.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_85.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_58.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_73.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_38.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_15.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_93.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_17.png (deflated 3%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_72.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_5.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_9.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_84.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_75.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_56.png (deflated 4%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_68.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_32.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_99.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_29.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_30.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_47.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_69.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_100.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_61.png (deflated 3%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_2.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_42.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_89.png (deflated 2%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/prediction/prediction_94.png (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_97.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_53.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_82.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_31.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_22.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_42.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_77.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_2.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_72.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_27.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_39.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_68.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_20.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_12.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_34.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_10.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_9.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_35.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_21.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_15.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_81.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_71.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_45.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_94.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_48.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_73.png (deflated 1%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_69.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_24.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_78.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_58.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_70.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_91.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_52.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_90.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_18.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_62.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_1.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_61.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_84.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_33.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_37.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_63.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_95.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_64.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_59.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_86.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_51.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_76.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_50.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_56.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_79.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_89.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_3.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_47.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_8.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_60.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_5.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_32.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_19.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_67.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_100.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_40.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_17.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_11.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_13.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_99.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_43.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_85.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_54.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_29.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_75.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_57.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_41.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_98.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_30.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_93.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_38.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_96.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_23.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_87.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_83.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_46.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_26.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/concat/concat_25.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/ (stored 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_98.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_5.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_45.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_64.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_86.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_81.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_33.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_20.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_78.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_70.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_18.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_40.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_51.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_43.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_83.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_8.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_24.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_75.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_1.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_32.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_13.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_37.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_73.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_94.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_63.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_97.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_19.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_68.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_82.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_90.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_76.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_58.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_54.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_72.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_69.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_23.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_26.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_48.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_39.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_35.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_61.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_9.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_57.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_56.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_31.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_12.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_62.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_89.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_67.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_93.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_38.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_99.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_27.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_11.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_17.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_50.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_41.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_52.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_21.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_60.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_91.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_96.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_15.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_25.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_34.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_22.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_42.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_85.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_53.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_87.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_10.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_30.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_46.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_29.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_95.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_71.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_79.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_77.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_2.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_100.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_84.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_59.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_47.png (deflated 0%)
#   adding: content/CIL-street/code/patch_based/results_unet/train/overlay/overlay_3.png (deflated 0%)
